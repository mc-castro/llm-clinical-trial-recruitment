# %% [markdown]
# ## Imports

# %%
import pandas as pd
from google.colab import userdata, drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Extract Data

# %%
clinical_trials_df = pd.read_csv("/content/drive/My Drive/Mestrado/Dissertação/mimic-iv-ext-cardiac-disease/processed/processed_studies.csv")

# %% [markdown]
# ## Transform Data

# %%
# Sorteio aleatório com semente fixa para reprodutibilidade
sample_validation = clinical_trials_df.sample(n=88, random_state=42)

# %%
sample_validation
# Out:
#           nct_id                                     official_title  \
# 521  NCT06423625  Developing a Prediction Score Model for Predic...
# 737  NCT00090259  A Multi-center, Double-Blind, Randomized, Para...
# 740  NCT05625269  The Effect of Education and Follow-up Program ...
# 660  NCT02394470  BioImpedentiometry and Lung UltraSound Examina...
# 411  NCT00287209  Reduction of Atrial Fibrillation Study in Pati...
# ..           ...                                                ...
# 67   NCT04336995  Echocardiographic Assessment of Pulmonary Tran...
# 318  NCT03518021  NTNU Intranasal Naloxone Trial - a Double Blin...
# 548  NCT02847585                                                NaN
# 998  NCT01620398  The Brazilian Cardioprotective Nutritional Pro...
# 714  NCT02845037  A Rising Single Oral Dose Study to Investigate...
#
#                                   eligibility_criteria  \
# 521  Inclusion Criteria:\n\n* Age \> 18 yrs\n* Inde...
# ...

# %% [markdown]
# ## Load Data

# %%
sample_validation.to_csv('/content/drive/My Drive/Mestrado/Dissertação/mimic-iv-ext-cardiac-disease/processed/sample_audit_extraction.csv', index=False)
